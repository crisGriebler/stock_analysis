# %% [markdown]
# # 5. Análises do mercado financeiro

# %% [markdown]
# Será ralizado uma análise estatítica do desempenho de ativos do mercado nacional e internacional.
# Serão utilizadas algumas ferramentas de dados e de visualização para explorar os dados e obter insights sobre o desempenho de algumas ações.
#
# Faremos uma análise exploratória dos dados onde vamos calcular métricas importantes no mercado financeiro, como retorno, volatilidade, drawdown, distribuições, skewness, dentre outras.

# %% [markdown]
# ## 5.1. Obtenção dos dados

# %% [markdown]
# Utilizando a biblioteca yfinance, vamos obter os dados de negociação para algum papel, como por exemplo PETR4

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Iniciando uma primeira análise da cotação da ação da Petrobras.

# %%
petro = yf.download("PETR4.SA", start="2017-01-01", end="2023-07-10")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
petro.Close.plot();

# %% [markdown]
# ## 5.3. Médias móveis

# %% [markdown]
# ### 5.3.1. O que são médias móveis?
#
# Porque elas são tão importantes no mercado financeiro?
#
# Algumas métricas com as quais podemos criar médias móveis: preço, retorno, volatilidade, drawdown

# %% [markdown]
# ### 5.3.2. Médias móveis do preço

# %%
petro.Close.head(10)
# Out:
# Date
# 2017-01-02    14.66
# 2017-01-03    15.50
# 2017-01-04    15.50
# 2017-01-05    15.75
# 2017-01-06    15.66
# 2017-01-09    15.33
# 2017-01-10    15.48
# 2017-01-11    15.66
# 2017-01-12    15.90
# 2017-01-13    15.68
# Name: Close, dtype: float64

# %%
petro.Close.rolling(5).mean()
# Out:
# Date
# 2017-01-02       NaN
# 2017-01-03       NaN
# 2017-01-04       NaN
# 2017-01-05       NaN
# 2017-01-06    15.414
#                ...
# 2023-07-03    30.426
# 2023-07-04    30.336
# 2023-07-05    30.180
# 2023-07-06    29.904
# 2023-07-07    29.898
# Name: Close, Length: 1622, dtype: float64

# %%
petro.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
petro.Close.rolling(5).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
petro.Close.rolling(10).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
petro.Close.rolling(50).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
petro.Close.rolling(100).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## 5.4. Retornos diários

# %%
petro.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2017-01-02  14.64  14.70  14.60  14.66   5.396193   7525700
# 2017-01-03  14.95  15.65  14.95  15.50   5.705389  39947800
# 2017-01-04  15.45  15.68  15.31  15.50   5.705389  37071700
# 2017-01-05  15.70  15.91  15.62  15.75   5.797411  47586300
# 2017-01-06  15.78  15.92  15.50  15.66   5.764282  25592000

# %% [markdown]
# Calculando os retornos diários

# %%
petro['Adj Close'].pct_change()
# Out:
# Date
# 2017-01-02         NaN
# 2017-01-03    0.057299
# 2017-01-04    0.000000
# 2017-01-05    0.016129
# 2017-01-06   -0.005714
#                 ...
# 2023-07-03    0.018625
# 2023-07-04    0.002327
# 2023-07-05   -0.001327
# 2023-07-06   -0.015277
# 2023-07-07   -0.005059
# Name: Adj Close, Length: 1622, dtype: float64

# %% [markdown]
# ### PCT_CHANGE Library
# Percentage change between the current and a prior element.
#
# Computes the percentage change from the immediately previous row by default. This is useful in comparing the percentage of change in a time series of elements.

# %%
retornos = pd.DataFrame(petro['Adj Close'].pct_change())
retornos
# Out:
#             Adj Close
# Date
# 2017-01-02        NaN
# 2017-01-03   0.057299
# 2017-01-04   0.000000
# 2017-01-05   0.016129
# 2017-01-06  -0.005714
# ...               ...
# 2023-07-03   0.018625
# 2023-07-04   0.002327
# 2023-07-05  -0.001327
# 2023-07-06  -0.015277
# 2023-07-07  -0.005059
#
# [1622 rows x 1 columns]

# %% [markdown]
# Gráfico dos retornos diários

# %%
retornos.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Retorno diário médio

# %%
retornos.mean()
# Out:
# Adj Close    0.001477
# dtype: float64

# %% [markdown]
# Média móvel dos retornos

# %%
retornos.rolling(50).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## 5.5. Volatilidade
#
# A medida mais básica de volatilidade que podemos ter é o desvio padrão

# %% [markdown]
# Calculando o desvio padrão dos retornos diários

# %%
retornos.std()
# Out:
# Adj Close    0.028894
# dtype: float64

# %% [markdown]
# So this is the volatility of PETR4 during this period.

# %% [markdown]
# E se quiséssemos visualizar a volatilidade em janelas de tempo, isto é, o comportamento da volatilidade de PETR4 ao longo de períodos específicos de tempo, por exemplo, 10 dias?

# %%
janelas_vol = retornos.rolling(10).std()

# %%
janelas_vol.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## 5.6. Métricas estatísticas

# %%
retornos.describe()
# Out:
#          Adj Close
# count  1621.000000
# mean      0.001477
# std       0.028894
# min      -0.296978
# 25%      -0.012403
# 50%       0.001276
# 75%       0.015599
# max       0.222222

# %% [markdown]
# ## 5.7. Distribuição dos retornos

# %% [markdown]
# Forma de entender onde os retornos se "concentram" com o tempo

# %%
retornos.plot.hist(bins = 100);

# %% [markdown]
# ## 5.8. Drawdown em janela de 30 dias

# %% [markdown]
# Perda máxima em um determinado período - distância entre ganho máximo e a mínima

# %% [markdown]
# Maximum lost in a period, distance between the maximum value and lowest.

# %%
dd_30 = retornos.rolling(30).min()

# %%
dd_30.plot();

# %% [markdown]
# ## 5.9. Métricas de retorno acumulado

# %%
# Calculando o retorno acumulado
ret_acum = (retornos + 1).cumprod()
ret_acum
# Out:
#             Adj Close
# Date
# 2017-01-02        NaN
# 2017-01-03   1.057299
# 2017-01-04   1.057299
# 2017-01-05   1.074352
# 2017-01-06   1.068213
# ...               ...
# 2023-07-03   5.574300
# 2023-07-04   5.587272
# 2023-07-05   5.579860
# 2023-07-06   5.494614
# 2023-07-07   5.466817
#
# [1622 rows x 1 columns]

# %%
ret_acum.plot(figsize = (12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
# Vamos calcular agora o cumulativo máximo, ou seja, os picos atingidos ao longo do tempo
picos = ret_acum.cummax()
picos
# Out:
#             Adj Close
# Date
# 2017-01-02        NaN
# 2017-01-03   1.057299
# 2017-01-04   1.057299
# 2017-01-05   1.074352
# 2017-01-06   1.074352
# ...               ...
# 2023-07-03   5.902309
# 2023-07-04   5.902309
# 2023-07-05   5.902309
# 2023-07-06   5.902309
# 2023-07-07   5.902309
#
# [1622 rows x 1 columns]

# %%
picos.plot(figsize = (12,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Drawdown

# %% [markdown]
# Forma alternativa de cálculo do drawdown, considerando a diferença entre o retorno acumulado e os picos.

# %%
drawdown = (ret_acum - picos)/picos
drawdown.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Qual o drawdown máximo? É justamente o valor mais 'fundo' que o gráfico acima atinge

# %%
max_ddw = drawdown.min()

# %%
max_ddw*100
# Out:
# Adj Close   -63.356051
# dtype: float64

# %%
retornos['Retorno Acumulado'] = ret_acum
retornos['Picos'] = picos
retornos['Drawdowns'] = drawdown

# %%
retornos.head()
# Out:
#             Adj Close  Retorno Acumulado     Picos  Drawdowns
# Date
# 2017-01-02        NaN                NaN       NaN        NaN
# 2017-01-03   0.057299           1.057299  1.057299   0.000000
# 2017-01-04   0.000000           1.057299  1.057299   0.000000
# 2017-01-05   0.016129           1.074352  1.074352   0.000000
# 2017-01-06  -0.005714           1.068213  1.074352  -0.005714

# %%
retornos[['Retorno Acumulado', 'Picos']].plot(figsize = (12,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## 5.10. Normalização

# %% [markdown]
# Para explicar o conceito de normalização, vamos obter dados de vários papéis ao mesmo tempo para ficar mais fácil de exemplificar

# %%
acoes = ['PETR4.SA', 'POSI3.SA', 'MGLU3.SA', 'LREN3.SA', 'VALE3.SA']

# %%
data = yf.download(acoes, start="2019-01-01", end="2023-07-10")['Adj Close']
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data.head()
# Out:
#              LREN3.SA  MGLU3.SA  PETR4.SA  POSI3.SA   VALE3.SA
# Date
# 2019-01-02  35.599796  5.641578  9.238831  1.964033  36.257854
# 2019-01-03  35.150192  5.581216  9.465386  1.988583  34.774612
# 2019-01-04  33.801414  5.411354  9.492264  1.972216  37.038517
# 2019-01-07  33.024834  5.495374  9.642022  1.898565  36.839798
# 2019-01-08  34.087521  5.451089  9.584421  1.857647  37.194649

# %%
data.plot(figsize = (12,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Observe que é 'injusto' realizar uma comparação de um papel numa magnitude mais alta com outros que possuem o preço menor.

# %%
data.plot(figsize = (8,8))
plt.title('Ativos sem normalização', fontsize = 15)
plt.xlabel('Data')
plt.ylabel('Preço')
plt.show()

# %% [markdown]
# Introduzindo conceito da normalização

# %%
data.head()
# Out:
#              LREN3.SA  MGLU3.SA  PETR4.SA  POSI3.SA   VALE3.SA
# Date
# 2019-01-02  35.599796  5.641578  9.238831  1.964033  36.257854
# 2019-01-03  35.150192  5.581216  9.465386  1.988583  34.774612
# 2019-01-04  33.801414  5.411354  9.492264  1.972216  37.038517
# 2019-01-07  33.024834  5.495374  9.642022  1.898565  36.839798
# 2019-01-08  34.087521  5.451089  9.584421  1.857647  37.194649

# %%
normalizado = data/data.iloc[0]

# %%
normalizado.head()
# Out:
#             LREN3.SA  MGLU3.SA  PETR4.SA  POSI3.SA  VALE3.SA
# Date
# 2019-01-02  1.000000  1.000000  1.000000  1.000000  1.000000
# 2019-01-03  0.987371  0.989301  1.024522  1.012500  0.959092
# 2019-01-04  0.949483  0.959191  1.027431  1.004167  1.021531
# 2019-01-07  0.927669  0.974085  1.043641  0.966667  1.016050
# 2019-01-08  0.957520  0.966235  1.037406  0.945833  1.025837

# %%
normalizado.plot(figsize = (8,8))
plt.title('Ativos normalizados a 1', fontsize = 15)
plt.xlabel('Data')
plt.ylabel('Preço')
plt.show()

# %% [markdown]
# ## 5.1. Plot de cotação com volume

# %% [markdown]
# Vamos extrair dados para um ativo só

# %%
lren = yf.download('LREN3.SA', start = '2017-01-01', end = '2023-07-10')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
lren.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2017-01-02  18.775900  19.013674  18.702108  18.972677  16.774588   676417
# 2017-01-03  19.103865  19.677799  18.808697  19.554813  17.289286  2976064
# 2017-01-04  19.636805  19.833582  19.177654  19.382631  17.137045  2671030
# 2017-01-05  19.464622  19.587610  19.161257  19.202253  16.977564  3587596
# 2017-01-06  19.202253  19.202253  18.808697  18.980877  16.781834  2139141

# %%
lren.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
fig = plt.figure(figsize = (15,8))
gs = fig.add_gridspec(nrows = 6, ncols =1)
ax1 = fig.add_subplot(gs[0:5, 0])
ax2 = fig.add_subplot(gs[5, 0])

ax1.plot(lren.Close)
ax2.bar(lren.index, lren.Volume)
ax1.set_title('Fechamento | Volume | Cotação de LREN3')
# Out:
# Text(0.5, 1.0, 'Fechamento | Volume | Cotação de LREN3')

# %% [markdown]
# # 6. Estudo de caso: matriz de correlação

# %% [markdown]
# ## 6.1. Importando dados de FIIs, ETFs e BDRs

# %%
ativos = ['KNRI11.SA', 'ONEF11.SA', 'HCTR11.SA', 'HGLG11.SA',
          'HGBS11.SA', 'SMAL11.SA', 'IVVB11.SA', 'AAPL34.SA']

# %%
inicio = '2017-01-01'

# %%
precos_ativos = pd.DataFrame()

for i in ativos:
    precos_ativos[i] = yf.download(i, start = inicio)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
precos_ativos.head()
# Out:
#              KNRI11.SA  ONEF11.SA  HCTR11.SA   HGLG11.SA   HGBS11.SA  \
# Date
# 2017-01-02  138.095612  91.960693        NaN  107.094337  198.050491
# 2017-01-03  138.007675  92.158455        NaN  107.094337  197.463379
# 2017-01-04  139.688538  92.158455        NaN  107.094337  197.169830
# 2017-01-05  139.747177  90.971870        NaN  107.094337  196.876266
# 2017-01-06  140.675537  90.971870        NaN  107.094337  197.659073
#
#             SMAL11.SA  IVVB11.SA  AAPL34.SA
# Date
# 2017-01-02  54.000000      74.25   8.866890
# 2017-01-03  55.450001      74.25   8.773064
# 2017-01-04  56.990002      74.25   8.742568
# 2017-01-05  56.990002      74.25   8.791829
# 2017-01-06  56.500000      74.25   8.841088

# %% [markdown]
# ## 6.2. Importando dados de índices, commodities e criptomoedas

# %% [markdown]
# ### 6.2.1. Índices

# %%
import investpy

# %%
search_results = investpy.search_quotes(text = 'bvsp', products = ['indices'],
                      countries = ['brazil'], n_results = 10)

# %%
for search_result in search_results[:1]:
    print(search_result)
# Out:
# {"id_": 17920, "name": "Bovespa", "symbol": "BVSP", "country": "brazil", "tag": "/indices/bovespa", "pair_type": "indices", "exchange": "BM&FBovespa"}

# %%
ibov = search_result.retrieve_historical_data(from_date = '01/01/2017', to_date = '15/05/2022')

# %%
ibov.head()
# Out:
#                Open     High      Low    Close   Volume  Change Pct
# Date
# 2017-01-02  60227.0  60227.0  59371.0  59589.0   833730       -1.06
# 2017-01-03  59631.0  61815.0  59631.0  61814.0  3431250        3.73
# 2017-01-04  61811.0  61940.0  61302.0  61589.0  2928720       -0.36
# 2017-01-05  61594.0  62409.0  61594.0  62071.0  3415520        0.78
# 2017-01-06  62072.0  62072.0  61396.0  61665.0  2448150       -0.65

# %%
search_results = investpy.search_quotes(text = 'spx', products = ['indices'],
                      countries = ['united states'], n_results = 10)

for search_result in search_results[:1]:
    print(search_result)
# Out:
# {"id_": 166, "name": "S&P 500", "symbol": "US500", "country": "united states", "tag": "/indices/us-spx-500", "pair_type": "indices", "exchange": "NYSE"}

# %%
sp500 = search_result.retrieve_historical_data(from_date = '01/01/2017', to_date = '15/05/2022')

# %%
sp500.head()
# Out:
#                Open     High      Low    Close  Volume  Change Pct
# Date
# 2017-01-03  2251.57  2263.88  2245.13  2257.83       0        0.85
# 2017-01-04  2261.60  2272.82  2261.60  2270.75       0        0.57
# 2017-01-05  2268.18  2271.50  2260.45  2269.00       0       -0.08
# 2017-01-06  2271.14  2282.10  2264.06  2276.98       0        0.35
# 2017-01-09  2273.59  2275.49  2268.90  2268.90       0       -0.35

# %%
ibov.rename(columns = {'Close': 'IBOV'}, inplace = True)

# %%
ibov.head()
# Out:
#                Open     High      Low     IBOV   Volume  Change Pct
# Date
# 2017-01-02  60227.0  60227.0  59371.0  59589.0   833730       -1.06
# 2017-01-03  59631.0  61815.0  59631.0  61814.0  3431250        3.73
# 2017-01-04  61811.0  61940.0  61302.0  61589.0  2928720       -0.36
# 2017-01-05  61594.0  62409.0  61594.0  62071.0  3415520        0.78
# 2017-01-06  62072.0  62072.0  61396.0  61665.0  2448150       -0.65

# %%
sp500.rename(columns = {'Close': 'S&P500'}, inplace = True)

# %%
sp500.head()
# Out:
#                Open     High      Low   S&P500  Volume  Change Pct
# Date
# 2017-01-03  2251.57  2263.88  2245.13  2257.83       0        0.85
# 2017-01-04  2261.60  2272.82  2261.60  2270.75       0        0.57
# 2017-01-05  2268.18  2271.50  2260.45  2269.00       0       -0.08
# 2017-01-06  2271.14  2282.10  2264.06  2276.98       0        0.35
# 2017-01-09  2273.59  2275.49  2268.90  2268.90       0       -0.35

# %%
indices = pd.merge(ibov, sp500, how = 'inner', on = 'Date')

# %%
indices = indices[['IBOV', 'S&P500']]

# %%
indices
# Out:
#                 IBOV   S&P500
# Date
# 2017-01-03   61814.0  2257.83
# 2017-01-04   61589.0  2270.75
# 2017-01-05   62071.0  2269.00
# 2017-01-06   61665.0  2276.98
# 2017-01-09   61700.0  2268.90
# ...              ...      ...
# 2022-05-09  103250.0  3991.24
# 2022-05-10  103110.0  4001.05
# 2022-05-11  104397.0  3935.18
# 2022-05-12  105688.0  3930.08
# 2022-05-13  106924.0  4023.89
#
# [1294 rows x 2 columns]

# %% [markdown]
# ### 6.2.2. Commodities

# %%
# Café
search_results = investpy.search_quotes(text = 'coffe', products = ['commodities'],
                      countries = ['brazil'], n_results = 10)

for search_result in search_results[:1]:
    print(search_result)
# Out:
# {"id_": 964526, "name": "Arabica Coffee 4/5 Futures", "symbol": "ICFc1", "country": null, "tag": "/commodities/arabica-coffee-4-5", "pair_type": "commodities", "exchange": "BM&FBovespa"}

# %%
cafe = search_result.retrieve_historical_data(from_date = '01/01/2017', to_date = '15/05/2022')

# %%
cafe.head()
# Out:
#               Open    High     Low   Close  Volume  Change Pct
# Date
# 2017-01-02  160.15  162.00  160.15  159.85       6        0.00
# 2017-01-03  163.70  165.35  160.50  163.30     576        2.16
# 2017-01-04  163.70  170.00  163.55  168.95     376        3.46
# 2017-01-05  170.90  172.95  169.00  170.90     278        1.15
# 2017-01-06  170.95  173.10  170.00  171.00     452        0.06

# %%
cafe.Close.plot()

# %%
cafe.rename(columns = {'Close': 'cafe'}, inplace = True)

# %%
cafe.head()
# Out:
#               Open    High     Low    cafe  Volume  Change Pct
# Date
# 2017-01-02  160.15  162.00  160.15  159.85       6        0.00
# 2017-01-03  163.70  165.35  160.50  163.30     576        2.16
# 2017-01-04  163.70  170.00  163.55  168.95     376        3.46
# 2017-01-05  170.90  172.95  169.00  170.90     278        1.15
# 2017-01-06  170.95  173.10  170.00  171.00     452        0.06

# %%
# Soja
search_results = investpy.search_quotes(text = 'soy', products = ['commodities'],
                      countries = ['brazil'], n_results = 10)

for search_result in search_results[:1]:
    print(search_result)
# Out:
# {"id_": 964523, "name": "US Soybeans Futures", "symbol": "SJCc1", "country": null, "tag": "/commodities/us-soybeans?cid=964523", "pair_type": "commodities", "exchange": "BM&FBovespa"}

# %%
soja = search_result.retrieve_historical_data(from_date = '01/01/2017', to_date = '15/05/2022')

# %%
soja.Close.plot()

# %%
soja.rename(columns = {'Close': 'soja'}, inplace = True)

# %%
# Etanol
search_results = investpy.search_quotes(text = 'ethanol', products = ['commodities'],
                      countries = ['brazil'], n_results = 10)

for search_result in search_results[:1]:
    print(search_result)
# Out:
# {"id_": 964525, "name": "Ethanol Futures", "symbol": "ETHc1", "country": null, "tag": "/commodities/ethanol-futures?cid=964525", "pair_type": "commodities", "exchange": "BM&FBovespa"}

# %%
etanol = search_result.retrieve_historical_data(from_date = '01/01/2017', to_date = '15/05/2022')

# %%
etanol.Close.plot()

# %%
etanol.rename(columns = {'Close': 'etanol'}, inplace = True)

# %%
interm = pd.merge(cafe, soja, how = 'inner', on = 'Date')
commodities = pd.merge(interm, etanol, how = 'inner', on = 'Date')

# %%
commodities.head()
# Out:
#             Open_x  High_x   Low_x    cafe  Volume_x  Change Pct_x  Open_y  \
# Date
# 2017-01-02  160.15  162.00  160.15  159.85         6          0.00   22.33
# 2017-01-03  163.70  165.35  160.50  163.30       576          2.16   22.05
# 2017-01-04  163.70  170.00  163.55  168.95       376          3.46   21.99
# 2017-01-05  170.90  172.95  169.00  170.90       278          1.15   22.26
# 2017-01-06  170.95  173.10  170.00  171.00       452          0.06   22.20
#
#             High_y  Low_y   soja  Volume_y  Change Pct_y    Open    High  \
# Date
# 2017-01-02   22.33  22.33  22.33         0          0.00  1925.0  1925.0
# 2017-01-03   22.06  21.95  21.94       130         -1.75  1920.0  1935.0
# 2017-01-04   22.33  21.99  22.38       159          2.01  1930.0  1930.0
# 2017-01-05   22.35  22.26  22.32        35         -0.27  1915.0  1925.0
# 2017-01-06   22.20  21.99  21.93       117         -1.75  1925.0  1925.0
#
#                Low  etanol  Volume  Change Pct
# Date
# 2017-01-02  1925.0  1925.0      10        6.50
# 2017-01-03  1920.0  1930.0     152        0.26
# 2017-01-04  1920.0  1925.0      90       -0.26
# 2017-01-05  1915.0  1925.0     146        0.00
# 2017-01-06  1925.0  1925.0     150        0.00

# %%
from functools import reduce

# %%
lista_dfs = [cafe, soja, etanol]

# %%
commodities = reduce(lambda left, right: pd.merge(left, right, how = 'inner', on = 'Date'), lista_dfs)

# %%
commodities.head()
# Out:
#             Open_x  High_x   Low_x    cafe  Volume_x  Change Pct_x  Open_y  \
# Date
# 2017-01-02  160.15  162.00  160.15  159.85         6          0.00   22.33
# 2017-01-03  163.70  165.35  160.50  163.30       576          2.16   22.05
# 2017-01-04  163.70  170.00  163.55  168.95       376          3.46   21.99
# 2017-01-05  170.90  172.95  169.00  170.90       278          1.15   22.26
# 2017-01-06  170.95  173.10  170.00  171.00       452          0.06   22.20
#
#             High_y  Low_y   soja  Volume_y  Change Pct_y    Open    High  \
# Date
# 2017-01-02   22.33  22.33  22.33         0          0.00  1925.0  1925.0
# 2017-01-03   22.06  21.95  21.94       130         -1.75  1920.0  1935.0
# 2017-01-04   22.33  21.99  22.38       159          2.01  1930.0  1930.0
# 2017-01-05   22.35  22.26  22.32        35         -0.27  1915.0  1925.0
# 2017-01-06   22.20  21.99  21.93       117         -1.75  1925.0  1925.0
#
#                Low  etanol  Volume  Change Pct
# Date
# 2017-01-02  1925.0  1925.0      10        6.50
# 2017-01-03  1920.0  1930.0     152        0.26
# 2017-01-04  1920.0  1925.0      90       -0.26
# 2017-01-05  1915.0  1925.0     146        0.00
# 2017-01-06  1925.0  1925.0     150        0.00

# %%
commodities = commodities[['cafe','soja','etanol']]

# %%
commodities.head()
# Out:
#               cafe   soja  etanol
# Date
# 2017-01-02  159.85  22.33  1925.0
# 2017-01-03  163.30  21.94  1930.0
# 2017-01-04  168.95  22.38  1925.0
# 2017-01-05  170.90  22.32  1925.0
# 2017-01-06  171.00  21.93  1925.0

# %% [markdown]
# ## 6.3. Dados do dólar

# %%
dolar = yf.download('USDBRL=X', start = inicio)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dolar.head()
# Out:
#               Open    High     Low   Close  Adj Close  Volume
# Date
# 2017-01-02  3.2532  3.2797  3.2427  3.2532     3.2532       0
# 2017-01-03  3.2841  3.2897  3.2475  3.2840     3.2840       0
# 2017-01-04  3.2635  3.2643  3.2188  3.2635     3.2635       0
# 2017-01-05  3.2149  3.2276  3.1998  3.2141     3.2141       0
# 2017-01-06  3.1975  3.2118  3.1894  3.1977     3.1977       0

# %%
dolar.Close.plot()

# %%
dolar = pd.DataFrame(dolar.Close).rename(columns = {'Close': 'Dolar'})

# %%
dolar.head()
# Out:
#              Dolar
# Date
# 2017-01-02  3.2532
# 2017-01-03  3.2840
# 2017-01-04  3.2635
# 2017-01-05  3.2141
# 2017-01-06  3.1977

# %% [markdown]
# ## 6.4. Dados de ações

# %%
data.head()
# Out:
#             BPAC11.SA   LREN3.SA  MGLU3.SA  OIBR3.SA   PETR4.SA   VALE3.SA  \
# Date
# 2019-01-02   5.773697  37.106575  5.641579      1.26  17.299591  39.107300
# 2019-01-03   6.012528  36.637947  5.581217      1.41  17.723814  37.507492
# 2019-01-04   6.225854  35.232075  5.411354      1.41  17.774143  39.949306
# 2019-01-07   6.353385  34.422630  5.495374      1.42  18.054560  39.734982
# 2019-01-08   6.235074  35.530289  5.451089      1.38  17.946711  40.117706
#
#             WEGE3.SA
# Date
# 2019-01-02  8.611479
# 2019-01-03  8.807847
# 2019-01-04  8.908426
# 2019-01-07  8.769531
# 2019-01-08  8.697689

# %% [markdown]
# ## 6.5. Juntando tudo num dataframe só

# %%
# Dados de ações
data.index = pd.to_datetime(data.index)
# Dados de FIIs, ETFs e BDRs
precos_ativos.index = pd.to_datetime(precos_ativos.index)
# Dados de índices
indices.index = pd.to_datetime(indices.index)
# Dados de commodities
commodities.index = pd.to_datetime(commodities.index)
# Dados de criptomoedas
cripto.index = pd.to_datetime(cripto.index)
# Cotação do dólar
dolar.index = pd.to_datetime(dolar.index)

# %%
dfs = [data, precos_ativos, indices, commodities, cripto, dolar]

# %%
df_final = reduce(lambda left, right: pd.merge(left, right, how = 'inner', on = 'Date'), dfs)

# %%
df_final.head()
# Out:
.000000
#
# [23 rows x 23 columns]

# %%
sns.heatmap(df_final.corr())

# %%
plt.figure(figsize = (16,8))

sns.heatmap(df_final.corr(),
           vmin = -1, vmax = 1, annot = True, cmap = 'BrBG')

# %% [markdown]
# # 7. Estudo de caso: comparação de carteira com o IBOV

# %% [markdown]
# Simplificação: vamos simular um único aporte feito no primeiro dia

# %% [markdown]
# ## 7.1. Importando dados

# %%
ativos = ['PETR4','VALE3', 'ABEV3', 'WEGE3', 'EMBR3', 'RADL3', 'CVCB3', 'CIEL3', 'OIBR3', 'KNRI11']

# %%
ativos = [i + '.SA' for i in ativos]

# %%
inicio = '2020-01-01'
fim = '2022-05-15'

# %%
df = yf.download(ativos, start = inicio, end = fim)['Adj Close']
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
df.head()
# Out:
#              ABEV3.SA  CIEL3.SA   CVCB3.SA   EMBR3.SA   KNRI11.SA  OIBR3.SA  \
# Date
# 2020-01-02  17.917433  7.810114  44.709999  20.200001  197.204117      0.86
# 2020-01-03  17.665468  7.709867  44.200001  20.410000  197.204117      0.86
# 2020-01-06  17.749458  7.518486  43.820000  20.379999  195.603561      0.92
# 2020-01-07  17.786785  7.299767  44.400002  20.500000  196.364319      0.94
# 2020-01-08  17.702797  7.135728  44.340000  20.330000  185.249344      0.92
#
#              PETR4.SA   RADL3.SA   VALE3.SA   WEGE3.SA
# Date
# 2020-01-02  22.807089  22.584095  42.689388  17.142605
# 2020-01-03  22.621363  22.080606  42.375088  16.923700
# 2020-01-06  22.888809  21.645958  42.123650  16.967484
# 2020-01-07  22.799664  21.348980  42.430092  17.098829
# 2020-01-08  22.658512  21.634159  42.437950  16.451843

# %% [markdown]
# ## 7.2. Normalização dos ativos

# %%
normalizado = df/df.iloc[0]

# %%
normalizado.plot(figsize = (8,7))

# %% [markdown]
# ## 7.3. Métricas básicas de carteira

# %% [markdown]
# Preços no dia do aporte

# %%
primeiro = df.iloc[0]

# %%
primeiro
# Out:
# ABEV3.SA      17.917433
# CIEL3.SA       7.810114
# CVCB3.SA      44.709999
# EMBR3.SA      20.200001
# KNRI11.SA    197.204117
# OIBR3.SA       0.860000
# PETR4.SA      22.807089
# RADL3.SA      22.584095
# VALE3.SA      42.689388
# WEGE3.SA      17.142605
# Name: 2020-01-02 00:00:00, dtype: float64

# %% [markdown]
# Se investimos R$ 1000 em cada papel, quantos papéis precisamos comprar de cada?

# %%
comprados = 1000/primeiro

# %%
comprados
# Out:
# ABEV3.SA       55.811567
# CIEL3.SA      128.039106
# CVCB3.SA       22.366361
# EMBR3.SA       49.504949
# KNRI11.SA       5.070888
# OIBR3.SA     1162.790678
# PETR4.SA       43.846017
# RADL3.SA       44.278949
# VALE3.SA       23.425025
# WEGE3.SA       58.334192
# Name: 2020-01-02 00:00:00, dtype: float64

# %%
# Número de papéis arredondados
round(comprados, 0)
# Out:
# ABEV3.SA       56.0
# CIEL3.SA      128.0
# CVCB3.SA       22.0
# EMBR3.SA       50.0
# KNRI11.SA       5.0
# OIBR3.SA     1163.0
# PETR4.SA       44.0
# RADL3.SA       44.0
# VALE3.SA       23.0
# WEGE3.SA       58.0
# Name: 2020-01-02 00:00:00, dtype: float64

# %%
comprados = round(comprados, 0)

# %%
comprados
# Out:
# ABEV3.SA       56.0
# CIEL3.SA      128.0
# CVCB3.SA       22.0
# EMBR3.SA       50.0
# KNRI11.SA       5.0
# OIBR3.SA     1163.0
# PETR4.SA       44.0
# RADL3.SA       44.0
# VALE3.SA       23.0
# WEGE3.SA       58.0
# 2020-01-08  1069.960019   996.974533  951.903000  976.072853  954.206909
#
#                PL Total
# Date
# 2020-01-02  9956.230535
# 2020-01-03  9878.318025
# 2020-01-06  9899.841455
# 2020-01-07  9917.436355
# 2020-01-08  9772.073831

# %%
PL.tail()
# Out:
#               ABEV3.SA    CIEL3.SA    CVCB3.SA    EMBR3.SA   KNRI11.SA  \
# Date
# 2022-05-09  766.639977  391.170868  247.500000  657.499981  662.500000
# 2022-05-10  768.879974  394.980988  261.580008  652.500010  659.199982
# 2022-05-11  781.199989  391.679993  247.279995  648.500013  659.000015
# 2022-05-12  810.879974  407.040009  261.799992  667.999983  652.600021
# 2022-05-13  814.239998  416.000000  287.320009  692.999983  656.750031
#
#               OIBR3.SA     PETR4.SA    RADL3.SA     VALE3.SA     WEGE3.SA  \
# Date
# 2022-05-09  802.469997  1415.039993  832.920013  1759.269951  1546.279991
# 2022-05-10  837.360033  1427.359940  834.679970  1737.420021  1514.960049
# 2022-05-11  814.099986  1477.079987  812.239960  1809.870056  1513.800022
# 2022-05-12  814.099986  1488.520081  827.199966  1791.700035  1531.779991
# 2022-05-13  802.469997  1507.880020  811.360023  1789.629944  1537.000000
#
#                PL Total
# Date
# 2022-05-09  9081.290771
# 2022-05-10  9088.920973
# 2022-05-11  9154.750016
# 2022-05-12  9253.620038
# 2022-05-13  9315.650005

# %% [markdown]
# Vamos obter agora os dados do IBOV para compará-lo com nossa carteira

# %%
ibov = yf.download('^BVSP', start = inicio, end = fim)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 2020-01-02  115652.0  118573.0  115649.0  118573.0   118573.0  5162700
# 2020-01-03  118564.0  118792.0  117341.0  117707.0   117707.0  6834500
# 2020-01-06  117707.0  117707.0  116269.0  116878.0   116878.0  6570000
# 2020-01-07  116872.0  117076.0  115965.0  116662.0   116662.0  4854100
# 2020-01-08  116667.0  117335.0  115693.0  116247.0   116247.0  5910500

# %%
ibov.rename(columns = {'Close':'Ibov'}, inplace = True)

# %%
ibov = ibov[['Ibov']]

# %%
ibov
# Out:
#                 Ibov
# Date
# 2020-01-02  118573.0
# 2020-01-03  117707.0
# 2020-01-06  116878.0
# 2020-01-07  116662.0
# 2020-01-08  116247.0
# ...              ...
# 2022-05-09  103250.0
# 2022-05-10  103110.0
# 2022-05-11  104397.0
# 2022-05-12  105688.0
# 2022-05-13  106924.0
#
# [586 rows x 1 columns]

# %% [markdown]
# Agora vamos juntar os dados das tabelas do IBOV e da nossa carteira

# %%
novo_df = pd.merge(ibov, PL, how = 'inner', on = 'Date')

# %%
novo_df.head()
# Out:
#                 Ibov     ABEV3.SA    CIEL3.SA    CVCB3.SA     EMBR3.SA  \
# Date
# 2020-01-02  118573.0  1003.376236  999.694580  983.619980  1010.000038
# 2020-01-03  117707.0   989.266220  986.862915  972.400017  1020.499992
# 2020-01-06  116878.0   993.969666  962.366272  964.039993  1018.999958
# 2020-01-07  116662.0   996.059967  934.370239  976.800034  1025.000000
# 2020-01-08  116247.0   991.356628  913.373169  975.480003  1016.499996
#
#              KNRI11.SA     OIBR3.SA     PETR4.SA    RADL3.SA    VALE3.SA  \
# Date
# 2020-01-02  986.020584  1000.180017  1003.511909  993.700180  981.855930
# 2020-01-03  986.020584  1000.180017   995.339958  971.546684  974.627018
# 2020-01-06  978.017807  1069.960019  1007.107605  952.422150  968.843941
# 2020-01-07  981.821594  1093.219997  1003.185196  939.355118  975.892113
# 2020-01-08  926.246719  1069.960019   996.974533  951.903000  976.072853
# Date
# 2022-05-09  80.232557  141.008789  83.820053  179.178013  155.518955
# 2022-05-10  83.720932  142.236472  83.997164  176.952643  152.368914
# 2022-05-11  81.395346  147.191077  81.738937  184.331530  152.252243
# 2022-05-12  81.395346  148.331083  83.244422  182.480951  154.060600
# 2022-05-13  80.232557  150.260301  81.650385  182.270116  154.585609
#
#              PL Total
# Date
# 2022-05-09  91.212138
# 2022-05-10  91.288776
# 2022-05-11  91.949960
# 2022-05-12  92.943007
# 2022-05-13  93.566034

# %%
novo_normalizado[['Ibov','PL Total']].plot(figsize = (8,6))

# %% [markdown]
# E se o usuário conseguisse determinar quanto ele investiria em cada ativo?

# %%
ativos
# Out:
# ['PETR4.SA',
#  'VALE3.SA',
#  'ABEV3.SA',
#  'WEGE3.SA',
#  'EMBR3.SA',
#  'RADL3.SA',
#  'CVCB3.SA',
#  'CIEL3.SA',
#  'OIBR3.SA',
#  'KNRI11.SA']

# %%
alocacoes = {'PETR4.SA':2000,
 'VALE3.SA':2000,
 'ABEV3.SA':1000,
 'WEGE3.SA':1000,
 'EMBR3.SA':500,
 'RADL3.SA':500,
 'CVCB3.SA':500,
 'CIEL3.SA':500,
 'OIBR3.SA':500,
 'KNRI11.SA':1500}

# %%
alocacoes
# Out:
# {'PETR4.SA': 2000,
#  'VALE3.SA': 2000,
#  'ABEV3.SA': 1000,
#  'WEGE3.SA': 1000,
#  'EMBR3.SA': 500,
#  'RADL3.SA': 500,
#  'CVCB3.SA': 500,
#  'CIEL3.SA': 500,
#  'OIBR3.SA': 500,
#  'KNRI11.SA': 1500}

# %%
alocacoes.keys()
# Out:
# dict_keys(['PETR4.SA', 'VALE3.SA', 'ABEV3.SA', 'WEGE3.SA', 'EMBR3.SA', 'RADL3.SA', 'CVCB3.SA', 'CIEL3.SA', 'OIBR3.SA', 'KNRI11.SA'])

# %%
alocacoes_df = pd.Series(data = alocacoes, index = list(alocacoes.keys()))

# %%
alocacoes.values()
# Out:
# dict_values([2000, 2000, 1000, 1000, 500, 500, 500, 500, 500, 1500])

# %%
sum(alocacoes.values())
# Out:
# 10000

# %% [markdown]
# Obtendo preços dos ativos no primeiro dia do investimento

# %%
primeiro = df.iloc[0]

# %%
primeiro
# Out:
# ABEV3.SA      17.917433
# CIEL3.SA       7.810114
# CVCB3.SA      44.709999
# EMBR3.SA      20.200001
# KNRI11.SA    197.204117
# OIBR3.SA       0.860000
# PETR4.SA      22.807089
# RADL3.SA      22.584095
# VALE3.SA      42.689388
# WEGE3.SA      17.142605
# Name: 2020-01-02 00:00:00, dtype: float64

# %% [markdown]
# Quantidade de papéis comprados de cada ativo (determinados no primeiro dia)

# %%
compras = alocacoes_df/primeiro

# %%
compras = round(compras, 0)

# %%
compras
# Out:
# ABEV3.SA      56.0
# CIEL3.SA      64.0
# CVCB3.SA      11.0
# EMBR3.SA      25.0
# KNRI11.SA      8.0
# OIBR3.SA     581.0
# PETR4.SA      88.0
# RADL3.SA      22.0
# VALE3.SA      47.0
# WEGE3.SA      58.0
# dtype: float64

# %% [markdown]
# Criando um dataframe que contém a posição diária de cada ativo

# %%
01-02  100.000000  100.000000  100.000000  100.000000  100.000000
# 2020-01-03  100.000000  100.000000   99.185665   97.770606   99.263750
# 2020-01-06   99.188376  106.976744  100.358311   95.846028   98.674756
# 2020-01-07   99.574148  109.302323   99.967443   94.531040   99.392597
# 2020-01-08   93.937868  106.976744   99.348550   95.793784   99.411006
#
#               WEGE3.SA    PL Total
# Date
# 2020-01-02  100.000000  100.000000
# 2020-01-03   98.723038   99.248403
# 2020-01-06   98.978444   99.389998
# 2020-01-07   99.744639   99.616354
# 2020-01-08   95.970498   97.990119

# %%
novo_normalizado_02.tail()
# Out:
#                  Ibov   ABEV3.SA   CIEL3.SA   CVCB3.SA   EMBR3.SA  KNRI11.SA  \
# Date
# 2022-05-09  87.077159  76.406033  39.129038  25.162157  65.099006  67.189267
# 2022-05-10  86.959088  76.629279  39.510166  26.593605  64.603959  66.854586
# 2022-05-11  88.044496  77.857135  39.179966  25.139790  64.207920  66.834306
# 2022-05-12  89.133277  80.815146  40.716436  26.615969  66.138610  66.185233
# 2022-05-13  90.175672  81.150018  41.612709  29.210469  68.613857  66.606118
#
#              OIBR3.SA    PETR4.SA   RADL3.SA    VALE3.SA    WEGE3.SA  \
# Date
# 2022-05-09  80.232557  141.008789  83.820053  179.178013  155.518955
# 2022-05-10  83.720932  142.236472  83.997164  176.952643  152.368914
# 2022-05-11  81.395346  147.191077  81.738937  184.331530  152.252243
# 2022-05-12  81.395346  148.331083  83.244422  182.480951  154.060600
# 2022-05-13  80.232557  150.260301  81.650385  182.270116  154.585609
#
#               PL Total
# Date
# 2022-05-09  111.719971
# 2022-05-10  111.426227
# 2022-05-11  113.654878
# 2022-05-12  114.203785
# 2022-05-13  114.855645

# %%
novo_normalizado_02.plot()

# %%
novo_normalizado_02[['Ibov','PL Total']].plot(figsize = (8,6))

# %% [markdown]
# **Exercício**
#
# Crie uma função que recebe um dicionário de alocações definido pelo usuário, e compara essa carteira com o Ibov. As datas de início e fim também devem ser definidas pelo usuário.

# %%
alocacoes = {'PETR4.SA':2000,
 'VALE3.SA':2000,
 'ABEV3.SA':1000}

# %%
ativos = ['PETR4.SA', 'VALE3.SA', 'ABEV3.SA']

# %%
def compara_carteiras(ativos, dicionario, inicio, fim):
    df = yf.download(ativos, start = inicio, end = fim)['Adj Close']
    alocacoes_df = pd.Series(data = dicionario, index = list(dicionario.keys()))
    primeiro = df.iloc[0]
    compras = alocacoes_df/primeiro
    compras = round(compras, 0)
    PL00 = df*compras
    PL00['PL Total'] = PL00.sum(axis = 1)
    ibov = yf.download('^BVSP', start = inicio, end = fim)
    ibov.rename(columns = {'Close':'Ibov'}, inplace = True)
    novo_df00 = pd.merge(ibov, PL00, how = 'inner', on = 'Date')
    novo_normalizado_00 = (novo_df00/novo_df00.iloc[0])*100
    novo_normalizado_00[['Ibov','PL Total']].plot(figsize = (8,6))

# %%
inicio
# Out:
# '2020-01-01'

# %%
fim
# Out:
# '2022-05-15'

# %%
compara_carteiras(ativos, alocacoes, inicio, fim)
# Out:
# [*********************100%***********************]  3 of 3 completed
# [*********************100%***********************]  1 of 1 completed

# %%
lista_ativos = ['PETR4.SA', 'MGLU3.SA', 'WEGE3.SA']

carteira = {'PETR4.SA':2000,
 'MGLU3.SA':3000,
 'WEGE3.SA':13000}

# %%
compara_carteiras(lista_ativos, carteira, inicio, fim)
# Out:
# [*********************100%***********************]  3 of 3 completed
# [*********************100%***********************]  1 of 1 completed
